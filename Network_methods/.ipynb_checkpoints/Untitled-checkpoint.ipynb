# %%
import gym
import time
import os
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, "../Environment/")
import halite_env as Env

# %%
from importlib import reload
reload(Env)
# Out:
# <module 'halite_env' from '../Environment/halite_env.py'>

# %%
num_players = 1
map_size = 7 # 7 x 7 map
HEnv = Env.HaliteEnv(num_players, map_size)

# %%
def Single_ship_env_initialization(map_size, num_players = 1):
    HEnv = Env.HaliteEnv(num_players, map_size)
    return Env.SingleShipEnv(HEnv, 1, map_size)

def check_position(env):
    print(env.state[:,:,:])

# %%
env = Single_ship_env_initialization(map_size)
_ = env.reset()

# %% [markdown]
# # Baselines

# %%
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines.common import set_global_seeds
from stable_baselines import PPO2, ACKTR
from stable_baselines.bench import Monitor
import stable_baselines
#reload(stable_baselines)
#from stable_baselines.logger import configure
#configure("/home/mango/Documents/haliteRL/tensorboard_ppo2", ['stdout','log','csv','tensorboard'])
from hyperparams_opt import hyperparam_optimization


MULTI = False
COMPARISON = False
obs_type = "raw"
n_timesteps = 100000
map_size = 7

# %%
def make_env(map_size, rank, seed=1234, log_dir=None):
    """
    Utility function for multiprocessed env.

    :param env_id: (str) the environment ID
    :param rank: (int) index of the subprocess
    :param seed: (int) the inital seed for RNG
    """
    if log_dir is None and log_dir != '':
        log_dir = "/tmp/gym/{}/".format(int(time.time()))
    os.makedirs(log_dir, exist_ok=True)

    def _init():
        set_global_seeds(seed + rank)
        env = Single_ship_env_initialization(map_size)
        
        env.seed(seed + rank)
        env = Monitor(env, os.path.join(log_dir, str(rank)), allow_early_resets=True)

        return env

    return _init

def evaluate(model, num_steps=1000):
    """
    Evaluate a RL agent
    :param model: (BaseRLModel object) the RL Agent
    :param num_steps: (int) number of timesteps to evaluate it
    :return: (float) Mean reward
    """
    episode_rewards = [[0.0] for _ in range(env.num_envs)]
    obs = env.reset()
    for i in range(num_steps):
        # _states are only useful when using LSTM policies
        actions, _states = model.predict(obs)
        # here, action, rewards and dones are arrays
        # because we are using vectorized env
        obs, rewards, dones, info = env.step(actions)

        # Stats
        for j in range(env.num_envs):
            episode_rewards[j][-1] += rewards[j]
            if dones[j]:
                episode_rewards[j].append(0.0)

    mean_rewards = [0.0 for _ in range(env.num_envs)]
    n_episodes = 0
    for i in range(env.num_envs):
        mean_rewards[i] = np.mean(episode_rewards[i])
        n_episodes += len(episode_rewards[i])

    # Compute mean reward
    mean_reward = round(np.mean(mean_rewards), 1)
    print("Mean reward:", mean_reward, "Num episodes:", n_episodes)

    return mean_reward





if MULTI:
    num_cpu = 32  # Number of processes to use
    # Create the vectorized environment
    env = SubprocVecEnv([make_env(map_size, i) for i in range(num_cpu)])
else:
    # env = SingleSnek(obs_type="rgb", n_food=3)
    env = Single_ship_env_initialization(map_size)
    # The algorithms require a vectorized environment to run
    env = DummyVecEnv([lambda: env])


ob = env.reset()

# %%
import yaml

with open('hyperparams.yml', 'r') as f:
            hyperparams_dict = yaml.load(f)
            hyperparams = hyperparams_dict['halite']

print(hyperparams)
print(hyperparams.get('n_envs', 1))
print(hyperparams)

#hyperparams.get('n_envs')
# Out:
# /home/mango/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   after removing the cwd from sys.path.
# {'policy': 'MlpPolicy', 'n_envs': 8, 'n_steps': 128, 'noptepochs': 4, 'nminibatches': 4, 'n_timesteps': 10000000.0, 'learning_rate': 'lin_2.5e-4', 'cliprange': 'lin_0.1', 'vf_coef': 0.5, 'ent_coef': 0.01}
# 8
# {'policy': 'MlpPolicy', 'n_envs': 8, 'n_steps': 128, 'noptepochs': 4, 'nminibatches': 4, 'n_timesteps': 10000000.0, 'learning_rate': 'lin_2.5e-4', 'cliprange': 'lin_0.1', 'vf_coef': 0.5, 'ent_coef': 0.01}

# %%
from stable_baselines import PPO2, A2C, ACER, ACKTR, DQN, HER, DDPG, TRPO, SAC

ALGOS = {
    'a2c': A2C,
    'acer': ACER,
    'acktr': ACKTR,
    'dqn': DQN,
    'ddpg': DDPG,
    'her': HER,
    'sac': SAC,
    'ppo2': PPO2,
    'trpo': TRPO
}

# %%
algo_ = algo = 'ppo2'
normalize = False 
tensorboard_log = './tensorboard_ppo2/'
n_trials = 10
n_timesteps = 10
n_jobs = 1
n_envs = 1
sampler = 'random' # one of: 'random','tpe'
pruner = 'halving' # one of: 'halving', 'median', 'none'
seed = int(time.time())

def create_env(n_envs):
            """
            Create the environment
            :param n_envs: (int)
            :return: (gym.Env)
            """
            
            global hyperparams

            if algo_ in ['dqn', 'ddpg']:
                if hyperparams.get('normalize', False):
                    print("WARNING: normalization not supported yet for DDPG/DQN")
                env = gym.make(env_id)
                env.seed(seed)
            else:
                if n_envs == 1:
                    env = DummyVecEnv([make_env(map_size, 0, seed)])
                else:
                    # env = SubprocVecEnv([make_env(env_id, i, args.seed) for i in range(n_envs)])
                    # On most env, SubprocVecEnv does not help and is quite memory hungry
                    env = DummyVecEnv([make_env(map_size, i, seed) for i in range(n_envs)])
                if normalize:
                    if args.verbose > 0:
                        if len(normalize_kwargs) > 0:
                            print("Normalization activated: {}".format(normalize_kwargs))
                        else:
                            print("Normalizing input and reward")
                    env = VecNormalize(env, **normalize_kwargs)
            # Optional Frame-stacking
            if hyperparams.get('frame_stack', False):
                n_stack = hyperparams['frame_stack']
                env = VecFrameStack(env, n_stack)
                print("Stacking {} frames".format(n_stack))
                del hyperparams['frame_stack']
            return env


def create_model(*_args, **kwargs):
                """
                Helper to create a model with different hyperparameters
                """
                return ALGOS[algo](env=create_env(n_envs), tensorboard_log=tensorboard_log,
                                        verbose=0, **kwargs)

# %%
if 'n_envs' in hyperparams.keys():
    del hyperparams['n_envs']
if 'n_timesteps' in hyperparams.keys():
    del hyperparams['n_timesteps']

data_frame = hyperparam_optimization(algo, create_model, create_env, n_trials=n_trials,
                                                 n_timesteps=n_timesteps, hyperparams=hyperparams,
                                                 n_jobs=n_jobs, sampler_method=sampler, 
                                                 pruner_method=pruner, verbose=1)
# Out:
# Sampler: random - Pruner: halving
# WARNING:tensorflow:From /home/mango/.local/lib/python3.6/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/mango/.local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/mango/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/mango/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# [I 2019-06-30 16:54:40,220] Finished trial#0 resulted in value: inf. Current best value is inf with parameters: {'batch_size': 32, 'n_steps': 2048, 'gamma': 0.999, 'lr': 0.1664672261412471, 'ent_coef': 0.010130230408794483, 'cliprange': 0.4, 'noptepochs': 5, 'lamdba': 0.95}.
# [I 2019-06-30 16:55:26,276] Finished trial#1 resulted in value: 6.512650489807129. Current best value is 6.512650489807129 with parameters: {'batch_size': 64, 'n_steps': 64, 'gamma': 0.995, 'lr': 0.0003073781785362607, 'ent_coef': 2.4945421193251008e-08, 'cliprange': 0.1, 'noptepochs': 10, 'lamdba': 0.9}.
# [I 2019-06-30 16:55:26,984] Finished trial#2 resulted in value: inf. Current best value is 6.512650489807129 with parameters: {'batch_size': 64, 'n_steps': 64, 'gamma': 0.995, 'lr': 0.0003073781785362607, 'ent_coef': 2.4945421193251008e-08, 'cliprange': 0.1, 'noptepochs': 10, 'lamdba': 0.9}.
# [I 2019-06-30 16:55:48,627] Finished trial#3 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 16:55:52,275] Setting status of trial#4 as TrialState.PRUNED.
# [I 2019-06-30 16:55:56,196] Setting status of trial#5 as TrialState.PRUNED.
# [I 2019-06-30 16:56:00,195] Setting status of trial#6 as TrialState.PRUNED.
# [I 2019-06-30 16:56:00,984] Finished trial#7 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 16:56:04,697] Setting status of trial#8 as TrialState.PRUNED.
# [I 2019-06-30 16:56:05,479] Finished trial#9 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 16:56:09,953] Setting status of trial#10 as TrialState.PRUNED.
# [I 2019-06-30 16:56:10,769] Finished trial#11 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 16:56:11,483] Finished trial#12 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 16:56:15,360] Setting status of trial#13 as TrialState.PRUNED.
# [I 2019-06-30 16:56:19,141] Setting status of trial#14 as TrialState.PRUNED.
# [I 2019-06-30 16:56:23,179] Setting status of trial#15 as TrialState.PRUNED.
# [I 2019-06-30 16:56:27,210] Setting status of trial#16 as TrialState.PRUNED.
# [I 2019-06-30 16:56:40,880] Setting status of trial#17 as TrialState.PRUNED.
# [I 2019-06-30 16:56:54,627] Setting status of trial#18 as TrialState.PRUNED.
# [I 2019-06-30 16:56:55,425] Finished trial#19 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 16:56:59,080] Setting status of trial#20 as TrialState.PRUNED.
# [I 2019-06-30 16:57:03,678] Setting status of trial#21 as TrialState.PRUNED.
# [I 2019-06-30 16:57:48,807] Finished trial#22 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 16:57:53,723] Setting status of trial#23 as TrialState.PRUNED.
# [I 2019-06-30 16:57:58,270] Setting status of trial#24 as TrialState.PRUNED.
# [I 2019-06-30 16:57:59,093] Finished trial#25 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 16:58:03,158] Setting status of trial#26 as TrialState.PRUNED.
# [I 2019-06-30 16:58:08,021] Setting status of trial#27 as TrialState.PRUNED.
# [I 2019-06-30 16:58:12,026] Setting status of trial#28 as TrialState.PRUNED.
# [I 2019-06-30 16:58:12,816] Finished trial#29 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 16:58:16,543] Setting status of trial#30 as TrialState.PRUNED.
# [I 2019-06-30 16:58:17,338] Finished trial#31 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 16:58:21,876] Setting status of trial#32 as TrialState.PRUNED.
# [I 2019-06-30 16:59:06,024] Finished trial#33 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 16:59:09,881] Setting status of trial#34 as TrialState.PRUNED.
# [I 2019-06-30 16:59:13,805] Setting status of trial#35 as TrialState.PRUNED.
# [I 2019-06-30 16:59:19,144] Setting status of trial#36 as TrialState.PRUNED.
# [I 2019-06-30 16:59:22,859] Setting status of trial#37 as TrialState.PRUNED.
# [I 2019-06-30 16:59:26,847] Setting status of trial#38 as TrialState.PRUNED.
# [I 2019-06-30 16:59:30,710] Setting status of trial#39 as TrialState.PRUNED.
# [I 2019-06-30 16:59:31,513] Finished trial#40 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 16:59:35,520] Setting status of trial#41 as TrialState.PRUNED.
# [I 2019-06-30 16:59:36,338] Finished trial#42 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 16:59:41,381] Setting status of trial#43 as TrialState.PRUNED.
# [I 2019-06-30 16:59:42,187] Finished trial#44 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:00:28,639] Finished trial#45 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:00:29,372] Finished trial#46 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:00:30,102] Finished trial#47 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:00:33,820] Setting status of trial#48 as TrialState.PRUNED.
# [I 2019-06-30 17:00:37,760] Setting status of trial#49 as TrialState.PRUNED.
# [I 2019-06-30 17:00:38,585] Finished trial#50 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:01:03,677] Finished trial#51 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:01:07,346] Setting status of trial#52 as TrialState.PRUNED.
# [I 2019-06-30 17:01:58,183] Finished trial#53 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:02:02,558] Finished trial#54 resulted in value: 4.190001487731934. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:02:06,648] Setting status of trial#55 as TrialState.PRUNED.
# [I 2019-06-30 17:02:10,488] Setting status of trial#56 as TrialState.PRUNED.
# [I 2019-06-30 17:02:11,304] Finished trial#57 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:02:12,044] Finished trial#58 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:02:33,210] Finished trial#59 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:02:37,502] Setting status of trial#60 as TrialState.PRUNED.
# [I 2019-06-30 17:02:43,219] Setting status of trial#61 as TrialState.PRUNED.
# [I 2019-06-30 17:02:44,031] Finished trial#62 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:02:47,914] Setting status of trial#63 as TrialState.PRUNED.
# [I 2019-06-30 17:02:51,908] Setting status of trial#64 as TrialState.PRUNED.
# [I 2019-06-30 17:02:52,729] Finished trial#65 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:02:53,482] Finished trial#66 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:02:57,356] Setting status of trial#67 as TrialState.PRUNED.
# [I 2019-06-30 17:03:01,133] Setting status of trial#68 as TrialState.PRUNED.
# [I 2019-06-30 17:03:05,004] Setting status of trial#69 as TrialState.PRUNED.
# [I 2019-06-30 17:03:05,820] Finished trial#70 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:03:06,557] Finished trial#71 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:03:10,941] Setting status of trial#72 as TrialState.PRUNED.
# [I 2019-06-30 17:03:14,891] Setting status of trial#73 as TrialState.PRUNED.
# [I 2019-06-30 17:03:19,913] Setting status of trial#74 as TrialState.PRUNED.
# [I 2019-06-30 17:04:06,150] Finished trial#75 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:04:09,781] Setting status of trial#76 as TrialState.PRUNED.
# [I 2019-06-30 17:04:13,452] Setting status of trial#77 as TrialState.PRUNED.
# [I 2019-06-30 17:04:14,282] Finished trial#78 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:04:18,913] Setting status of trial#79 as TrialState.PRUNED.
# [I 2019-06-30 17:04:23,171] Setting status of trial#80 as TrialState.PRUNED.
# [I 2019-06-30 17:05:11,158] Finished trial#81 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:05:15,249] Setting status of trial#82 as TrialState.PRUNED.
# [I 2019-06-30 17:05:19,270] Setting status of trial#83 as TrialState.PRUNED.
# [I 2019-06-30 17:05:23,823] Finished trial#84 resulted in value: 4.190001487731934. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:06:10,185] Finished trial#85 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:06:55,186] Finished trial#86 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:07:06,959] Finished trial#87 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:07:10,663] Setting status of trial#88 as TrialState.PRUNED.
# [I 2019-06-30 17:07:11,499] Finished trial#89 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:07:15,385] Setting status of trial#90 as TrialState.PRUNED.
# [I 2019-06-30 17:08:03,317] Finished trial#91 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:08:07,385] Setting status of trial#92 as TrialState.PRUNED.
# [I 2019-06-30 17:08:20,500] Finished trial#93 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:08:25,459] Setting status of trial#94 as TrialState.PRUNED.
# [I 2019-06-30 17:08:29,634] Setting status of trial#95 as TrialState.PRUNED.
# [I 2019-06-30 17:09:17,108] Finished trial#96 resulted in value: 3.9899966716766357. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:09:17,837] Finished trial#97 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# [I 2019-06-30 17:09:21,902] Setting status of trial#98 as TrialState.PRUNED.
# [I 2019-06-30 17:09:22,729] Finished trial#99 resulted in value: inf. Current best value is 3.9899966716766357 with parameters: {'batch_size': 32, 'n_steps': 128, 'gamma': 0.9, 'lr': 0.14557916623227773, 'ent_coef': 0.0027996081984870843, 'cliprange': 0.4, 'noptepochs': 1, 'lamdba': 0.92}.
# Number of finished trials:  100
# Best trial:
# Value:  3.9899966716766357
# Params:
#     batch_size: 32
#     n_steps: 128
#     gamma: 0.9
#     lr: 0.14557916623227773
#     ent_coef: 0.0027996081984870843
#     cliprange: 0.4
#     noptepochs: 1
#     lamdba: 0.92

# %%
data_frame
# Out:
#    number                state     value             datetime_start  \
#
# 0       0  TrialState.COMPLETE       inf 2019-06-30 16:54:38.939660
# 1       1  TrialState.COMPLETE  6.512650 2019-06-30 16:54:40.223206
# 2       2  TrialState.COMPLETE       inf 2019-06-30 16:55:26.278157
# 3       3  TrialState.COMPLETE  3.989997 2019-06-30 16:55:26.986481
# 4       4    TrialState.PRUNED  6.914258 2019-06-30 16:55:48.630213
# 5       5    TrialState.PRUNED  5.896439 2019-06-30 16:55:52.359845
# 6       6    TrialState.PRUNED  6.581452 2019-06-30 16:55:56.280105
# 7       7  TrialState.COMPLETE       inf 2019-06-30 16:56:00.280894
# 8       8    TrialState.PRUNED  6.648573 2019-06-30 16:56:00.986112
# 9       9  TrialState.COMPLETE       inf 2019-06-30 16:56:04.780294
# 10     10    TrialState.PRUNED  6.599050 2019-06-30 16:56:05.481575
# 11     11  TrialState.COMPLETE       inf 2019-06-30 16:56:10.037965
# 12     12  TrialState.COMPLETE       inf 2019-06-30 16:56:10.771259
# 13     13    TrialState.PRUNED  6.528604 2019-06-30 16:56:11.486234
# 14     14    TrialState.PRUNED  6.726693 2019-06-30 16:56:15.444356
# 15     15    TrialState.PRUNED  7.335818 2019-06-30 16:56:19.224905
# 16     16    TrialState.PRUNED  7.012576 2019-06-30 16:56:23.264279
# 17     17    TrialState.PRUNED  7.840066 2019-06-30 16:56:27.296500
# 18     18    TrialState.PRUNED  7.818910 2019-06-30 16:56:40.982046
# 19     19  TrialState.COMPLETE       inf 2019-06-30 16:56:54.711978
# 76 2019-06-30 17:04:09.783186         64       0.2  1.979823e-07  0.9000
# 77 2019-06-30 17:04:13.455222         32       0.4  4.407508e-08  0.9900
# 78 2019-06-30 17:04:14.261368         32       0.1  4.535172e-05  0.9950
# 79 2019-06-30 17:04:18.916416         64       0.4  5.920227e-07  0.9500
# 80 2019-06-30 17:04:23.173830         64       0.2  4.171213e-06  0.9800
# 81 2019-06-30 17:05:11.135657         32       0.2  3.021128e-04  0.9999
# 82 2019-06-30 17:05:15.251847        128       0.2  4.340422e-04  0.9999
# 83 2019-06-30 17:05:19.272529        128       0.4  9.881904e-06  0.9800
# 84 2019-06-30 17:05:23.800581        128       0.3  3.484406e-06  0.9800
# 85 2019-06-30 17:06:10.162684         64       0.2  6.318797e-07  0.9950
# 86 2019-06-30 17:06:55.162053        128       0.4  5.571091e-07  0.9990
# 87 2019-06-30 17:07:06.935780         64       0.4  2.561501e-08  0.9999
# 88 2019-06-30 17:07:10.666367        128       0.1  1.865667e-06  0.9900
# 89 2019-06-30 17:07:11.475320         32       0.2  7.487276e-03  0.9900
# 90 2019-06-30 17:07:15.388047        128       0.2  1.177676e-02  0.9500
# 91 2019-06-30 17:08:03.293033         32       0.3  9.137040e-02  0.9500
# 92 2019-06-30 17:08:07.387821        256       0.1  8.363819e-06  0.9000
# 93 2019-06-30 17:08:20.475605         64       0.3  5.950627e-02  0.9990
# 94 2019-06-30 17:08:25.461486         64       0.2  1.146534e-04  0.9000
# 95 2019-06-30 17:08:29.637740        128       0.1  1.645531e-02  0.9999
# 96 2019-06-30 17:09:17.082386         32       0.3  2.160490e-06  0.9800
# 97 2019-06-30 17:09:17.811307        256       0.3  1.327237e-05  0.9900
# 98 2019-06-30 17:09:21.905344        128       0.2  2.273479e-04  0.9900
# 99 2019-06-30 17:09:22.701912         32       0.3  1.427721e-02  0.9999
#
#            ... intermediate_values                                          \
#    lamdba  ...                   6         7         8         9        10
# 0    0.95  ...                 NaN       NaN       NaN       NaN       NaN
# 1    0.90  ...            6.728847  7.359266  8.235953  8.143588  8.229665
# 2    0.90  ...                 NaN       NaN       NaN       NaN       NaN
# 3    0.92  ...            3.989997  3.989997       NaN       NaN       NaN
# 4    0.90  ...                 NaN       NaN       NaN       NaN       NaN
# 5    0.92  ...                 NaN       NaN       NaN       NaN       NaN
# 6    0.98  ...                 NaN       NaN       NaN       NaN       NaN
# 7    0.90  ...                 NaN       NaN       NaN       NaN       NaN
# 8    0.95  ...                 NaN       NaN       NaN       NaN       NaN
# 9    0.98  ...                 NaN       NaN       NaN       NaN       NaN
# 10   0.95  ...                 NaN       NaN       NaN       NaN       NaN
# 11   0.95  ...                 NaN       NaN       NaN       NaN       NaN
# 12   0.80  ...                 NaN       NaN       NaN       NaN       NaN
# 13   0.80  ...                 NaN       NaN       NaN       NaN       NaN
# 14   0.92  ...                 NaN       NaN       NaN       NaN       NaN
# 15   0.90  ...                 NaN       NaN       NaN       NaN       NaN
# 16   0.80  ...                 NaN       NaN       NaN       NaN       NaN
# 17   1.00  ...                 NaN       NaN       NaN       NaN       NaN
# 18   0.92  ...                 NaN       NaN       NaN       NaN       NaN
# 19   0.80  ...                 NaN       NaN       NaN       NaN       NaN
# 20   0.98  ...                 NaN       NaN       NaN       NaN       NaN
# 21   0.80  ...                 NaN       NaN       NaN       NaN       NaN
# 22   1.00  ...            3.989997  3.989997  3.989997  3.989997  3.989997
# 23   0.90  ...                 NaN       NaN       NaN       NaN       NaN
# 24   0.80  ...                 NaN       NaN       NaN       NaN       NaN
# 25   0.80  ...                 NaN       NaN       NaN       NaN       NaN
# 26   1.00  ...                 NaN       NaN       NaN       NaN       NaN
# 27   0.92  ...                 NaN       NaN       NaN       NaN       NaN
# 28   0.95  ...                 NaN       NaN       NaN       NaN       NaN
# 29   0.95  ...                 NaN       NaN       NaN       NaN       NaN
# ..    ...  ...                 ...       ...       ...       ...       ...
# 70   0.95  ...                 NaN       NaN       NaN       NaN       NaN
# 71   0.92  ...                 NaN       NaN       NaN       NaN       NaN
# 72   1.00  ...                 NaN       NaN       NaN       NaN       NaN
# 73   0.98  ...                 NaN       NaN       NaN       NaN       NaN
# 74   1.00  ...                 NaN       NaN       NaN       NaN       NaN
# 75   0.95  ...            3.989997  3.989997  3.989997  3.989997  3.989997
# 76   0.99  ...                 NaN       NaN       NaN       NaN       NaN
# 77   1.00  ...                 NaN       NaN       NaN       NaN       NaN
# 78   0.95  ...                 NaN       NaN       NaN       NaN       NaN
# 79   0.95  ...                 NaN       NaN       NaN       NaN       NaN
# 80   1.00  ...                 NaN       NaN       NaN       NaN       NaN
# 81   0.92  ...            3.989997  3.989997  3.989997  3.989997  3.989997
# 82   0.95  ...                 NaN       NaN       NaN       NaN       NaN
# 83   1.00  ...                 NaN       NaN       NaN       NaN       NaN
# 84   0.95  ...                 NaN       NaN       NaN       NaN       NaN
# 85   0.90  ...            3.989997  3.989997  3.989997  3.989997  3.989997
# 86   0.90  ...            3.989997  3.989997  3.989997  3.989997  3.989997
# 87   0.90  ...                 NaN       NaN       NaN       NaN       NaN
# 88   0.92  ...                 NaN       NaN       NaN       NaN       NaN
# 89   0.99  ...                 NaN       NaN       NaN       NaN       NaN
# 90   0.92  ...                 NaN       NaN       NaN       NaN       NaN
# 91   0.92  ...            3.989997  3.989997  3.989997  3.989997  3.989997
# 92   0.90  ...                 NaN       NaN       NaN       NaN       NaN
# 93   0.80  ...                 NaN       NaN       NaN       NaN       NaN
# 94   0.80  ...                 NaN       NaN       NaN       NaN       NaN
# 95   0.95  ...                 NaN       NaN       NaN       NaN       NaN
# 96   0.92  ...            3.989997  3.989997  3.989997  3.989997  3.989997
# 97   0.92  ...                 NaN       NaN       NaN       NaN       NaN
# 98   0.90  ...                 NaN       NaN       NaN       NaN       NaN
# 99   0.92  ...                 NaN       NaN       NaN       NaN       NaN
#
#
#           11        12        13        14        15
# 0        NaN       NaN       NaN       NaN       NaN
# 1   8.579107  7.548820  7.098663  7.000854  6.512650
# 2        NaN       NaN       NaN       NaN       NaN
# 3        NaN       NaN       NaN       NaN       NaN
# 4        NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN       NaN       NaN       NaN
# 6        NaN       NaN       NaN       NaN       NaN
# 7        NaN       NaN       NaN       NaN       NaN
# 8        NaN       NaN       NaN       NaN       NaN
# 9        NaN       NaN       NaN       NaN       NaN
# 10       NaN       NaN       NaN       NaN       NaN
# 11       NaN       NaN       NaN       NaN       NaN
# 12       NaN       NaN       NaN       NaN       NaN
# 13       NaN       NaN       NaN       NaN       NaN
# 14       NaN       NaN       NaN       NaN       NaN
# 15       NaN       NaN       NaN       NaN       NaN
# 16       NaN       NaN       NaN       NaN       NaN
# 17       NaN       NaN       NaN       NaN       NaN
# 18       NaN       NaN       NaN       NaN       NaN
# 19       NaN       NaN       NaN       NaN       NaN
# 20       NaN       NaN       NaN       NaN       NaN
# 21       NaN       NaN       NaN       NaN       NaN
# 22  3.989997  3.989997  3.989997  3.989997  3.989997
# 23       NaN       NaN       NaN       NaN       NaN
# 24       NaN       NaN       NaN       NaN       NaN
# 25       NaN       NaN       NaN       NaN       NaN
# 26       NaN       NaN       NaN       NaN       NaN
# 27       NaN       NaN       NaN       NaN       NaN
# 28       NaN       NaN       NaN       NaN       NaN
# 29       NaN       NaN       NaN       NaN       NaN
# ..       ...       ...       ...       ...       ...
# 70       NaN       NaN       NaN       NaN       NaN
# 71       NaN       NaN       NaN       NaN       NaN
# 72       NaN       NaN       NaN       NaN       NaN
# 73       NaN       NaN       NaN       NaN       NaN
# 74       NaN       NaN       NaN       NaN       NaN
# 75  3.989997  3.989997  3.989997  3.989997  3.989997
# 76       NaN       NaN       NaN       NaN       NaN
# 77       NaN       NaN       NaN       NaN       NaN
# 78       NaN       NaN       NaN       NaN       NaN
# 79       NaN       NaN       NaN       NaN       NaN
# 80       NaN       NaN       NaN       NaN       NaN
# 81  3.989997  3.989997  3.989997  3.989997  3.989997
# 82       NaN       NaN       NaN       NaN       NaN
# 83       NaN       NaN       NaN       NaN       NaN
# 84       NaN       NaN       NaN       NaN       NaN
# 85  3.989997  3.989997  3.989997  3.989997  3.989997
# 86  3.989997  3.989997  3.989997  3.989997  3.989997
# 87       NaN       NaN       NaN       NaN       NaN
# 88       NaN       NaN       NaN       NaN       NaN
# 89       NaN       NaN       NaN       NaN       NaN
# 90       NaN       NaN       NaN       NaN       NaN
# 91  3.989997  3.989997  3.989997  3.989997  3.989997
# 92       NaN       NaN       NaN       NaN       NaN
# 93       NaN       NaN       NaN       NaN       NaN
# 94       NaN       NaN       NaN       NaN       NaN
# 95       NaN       NaN       NaN       NaN       NaN
# 96  3.989997  3.989997  3.989997  3.989997  3.989997
# 97       NaN       NaN       NaN       NaN       NaN
# 98       NaN       NaN       NaN       NaN       NaN
# 99       NaN       NaN       NaN       NaN       NaN
#
# [100 rows x 31 columns]
