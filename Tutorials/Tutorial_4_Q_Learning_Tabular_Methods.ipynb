# %% [markdown]
# # Tutorial 4: Q-learning with Tabular Methods
#
# In this tutorial we will finally see how to implement a Q-learning algorithm with Tabular Methods for our game.
#
# We gathered all the functions written in the previous tutorial in a script encode.py, that you can find in the Modules folder. In this way we can call the functions from there without having to redefine them. To do that we insert that folder among the paths that python searches for modules and libraries and then import the module as "cod"; you can call any function from that module as cod.function.
#
# ## Outline
# 1. define **greedy** and **$\epsilon$-greedy** policies, to choose actions given the state;
# 2. define an **update rule** for the Q-values, that is the way our algorithm is going to learn;
# 3. define a minimal **training cycle** for our agent.

# %%
import sys
sys.path.insert(0, "../Environment/")
sys.path.insert(0, "../Modules/")
import halite_env as Env
import encode as cod

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Policies
# This two policies are very simple and intuitive policies.
#
# The greedy one simply says: "given the state in which I am, I want to choose what I think is the best action for me", that is given $s$, choose $argmax_a Q(s,a)$.
#
# The epsilon-greedy policy is similar, but with probability epsilon (that as the name might suggest, is usually small) choose an action at random.

# %%
def greedy_policy(s_enc, q_values):
    """
    Parameters
    ----------
    s_enc : int, encoded state
    q_values : numpy matrix containing the Q-values
    
    Returns
    -------
    a : action that maximizes the Q-value given s_enc
    """
    return np.argmax(q_values[s_enc])

def e_greedy_policy(s_enc, q_values, eps = 0.01):
    """
    Parameters
    ----------
    s_enc : int, encoded state
    q_values : numpy matrix containing the Q-values
    eps : float representing the probability of choosing exploration over exploitation
    
    Returns
    -------
    a : random action with prob. eps and action that maximizes the Q-value given s_enc 
        with prob. (1-eps) 
    """
    u = np.random.rand()
    if u > eps:
        return np.argmax(q_values[s_enc])
    else:
        return np.random.randint(0, len(q_values[s_enc]))

# %% [markdown]
# The only possible problem with this implementation is that argmax is forced by numpy to return the first index if there are more global maxima.

# %%
#example
M = np.full(shape=(3,3),fill_value=0)
M[1]
greedy_policy(1, M)
# Out:
# 0

# %% [markdown]
# ## Update rule
#
# As we discussed in the second tutorial, the update rule is
#
# $$Q(s,a) = (1-\alpha)Q(s,a) + \alpha [r(s,a) + max_{a'}Q(s',a')]$$
# where
# - $\alpha$ is called learning rate and controls the trade-off between learning speed and algorithmic stability;
# - $s$ is the previous state;
# - $s'$ is the current state;
# - $a$ is the action that has taken us from $s$ to $s'$ (may be in a stochastic way);
# - $r(s,a)$ is the reward received this turn for the previous step
# - $a'$ is the action that we would take following the greedy policy in state $s'$ **BEFORE** the update.
#
# Implementing this simple rule we get the following function. We also introduced the possibility to use a discount factor gamma, that encodes the fact that "it's better to get one euro today than tomorrow". Anyway for our application is not relevant and we can keep it fixed at 1.

# %%
def update_q_v0(s_enc, a, r, sp_enc, ap, q_values, alpha = 0.1, gamma = 1):
    """
    Update rule of Q-learning.
    
    Parameters
    ----------
    s_enc: previous encoded state
    a : action taken last turn
    r : reward obtained for last action
    sp_enc: current encoded state
    ap : action that the agent would take following the greedy policy in state 𝑠p BEFORE the update
    q_values : numpy matrix containing the Q-values
    alpha : learning rate
    gamma : discount rate
    
    Returns
    -------
    updated Q-values
    
    """
    q_values[s_enc,a] = (1-alpha)*q_values[s_enc,a] + alpha*(r + gamma*q_values[sp_enc,ap])
    return q_values

# %% [markdown]
# A problem that we encountered with this update rule is that it is thought for a single episodic task (like "go out in the sea, get some fish and come back!") but our ship has to do it many times in a single match and this messes things up. What we want to do is to make the ship belive that it has finished its work once it comes back to the shipyard; therfore the term $max_{a'}Q(s',a')$ is set to zero if $s'$ is a terminal state (i.e. the ship is in the shipyard).
#
# We are not 100% sure of why this works and why the previous update not, but euristically there is a huge difference, namely in the previous case the ship learns not to pass from the shipyard, whereas in the new case everything works more or less fine.
#
# Anyway, here's the new update rule:

# %%
def update_q_v1(s, a, r, sp, ap, q_values, alpha = 0.1, gamma = 1, map_size = 7, h_lev = 3, n_actions = 5):
    """
    Update rule of Q-learning. Enforces Q-value = 0 for the terminal state.
    
    Parameters
    ----------
    s_enc: previous encoded state
    a : action taken last turn
    r : reward obtained for last action
    sp_enc: current encoded state
    ap : action that the agent would take following the greedy policy in state 𝑠p BEFORE the update
    q_values : numpy matrix containing the Q-values
    alpha : learning rate
    gamma : discount rate
    map_size : linear dimension of the squared map
    h_lev : number of quantization levels for the halite
    n_actions : number of actions that the agent can choose
    
    Returns
    -------
    updated Q-values
    
    """
    n_cells = map_size**2
    s_dec = cod.decode3D(s_enc, L1 = n_cells, L2 = h_lev**6, L3 = n_actions-1)
    sp_dec = cod.decode3D(sp_enc, L1 = n_cells, L2 = h_lev**6, L3 = n_actions-1)
    shipy_pos = (n_cells-1)/2 #shipyard is at the center of the map
    
    if (sp_dec[0] == shipy_pos and s_dec[0] != shipy_pos):
        # sp is terminal state -> enforce to have Q-value = 0 for all actions ap
        q_values[s_enc,a] = (1-alpha)*q_values[s_enc,a] + alpha*r 
    else:
        q_values[s_enc,a] = (1-alpha)*q_values[s_enc,a] + alpha*(r + gamma*q_values[sp_enc,ap]) # normal update
    return q_values

# %% [markdown]
# ## Training cycle

# %%
#@@@@@@@@@@@@@@@@@@@@@@
# Environment variables
#@@@@@@@@@@@@@@@@@@@@@@
NUM_PLAYERS = 1
MAP_SIZE = 7 # 7 x 7 map
TOT_TURNS = 400 # number of turns for each episode

#@@@@@@@@@@@@@@@@
# State variables
#@@@@@@@@@@@@@@@@
H_LEV = 3 # halite levels
N_CELLS = MAP_SIZE**2 # number of cells in a square map
N_STATES = N_CELLS*H_LEV**6*4
N_ACTIONS = 5 # no dropoffs, 1 action for staying still, 4 for moving in the cardinal directions
print("Total number of states to be experienced: ", N_STATES)

#@@@@@@@@@@@@@@@@@@@@
# Learning parameters
#@@@@@@@@@@@@@@@@@@@@
N_BATCH = 10 #100 # number of episodes in an epoch
MAX_EPOCHS = 200 # max number of epochs played before stopping (500 ~ 7.3 hours of training)
DISCOUNT_FACTOR = 1 - 1/TOT_TURNS #train ships as if each turn has a probability of 1/tot_turns of ending the game 
STD_REWARD = -0.01
LEARNING_RATE = 0.1
EPS_START = 0.5
# Out:
# Total number of states to be experienced:  142884

# %%
#@@@@@@@@@@@@@@@@@@@
# Learning variables
#@@@@@@@@@@@@@@@@@@@
q_values = np.zeros((N_STATES,N_ACTIONS)) #initialize to zero
#q_values = np.load("Q_values.npy") # or re-use the one already trained

# %% [markdown]
# So how it works an episode?

# %%
env = Env.HaliteEnv(NUM_PLAYERS, MAP_SIZE, episode_lenght = TOT_TURNS) # init environment
steps = 0
reward = 0 # cumulative reward of the episode
eps = EPS_START
# first mandatory step
steps = steps + 1
print("\nStep number %d:"%steps)
action_matrix = np.full((MAP_SIZE,MAP_SIZE), -1) # no ship, no action
shipyard_action = True # initially always choose to create a ship
# returns the matricial state, the array of players halite and a flag that is true if it's the final turn
state, players_halite, finish, _ = env.step(action_matrix, makeship = shipyard_action) 
#print("Cargo layer: \n", state[:,:,2])
current_halite = players_halite[0][0]
s_enc = cod.encode_state(state, map_size = MAP_SIZE, h_lev = H_LEV, n_actions = N_ACTIONS, debug=False)

while True:
    steps = steps + 1
    print("\nStep number %d:"%steps)
    print("Current halite: ", current_halite)
    a_enc = e_greedy_policy(s_enc, q_values, eps = eps) 
    a_mat = cod.scalar_to_matrix_action(a_enc, state, map_size = MAP_SIZE) #convert the action in matricial form

    # submit the action and get the new state
    state, players_halite, finish, _ = env.step(a_mat, makeship = False) 
    
    new_halite = players_halite[0][0]

    # compute the 1-ship reward as the halite increment of the player divided by the max halite 
    # plus a standard negative reward 
    r = (new_halite - current_halite)/1000 + STD_REWARD

    sp_enc = cod.encode_state(state, map_size = MAP_SIZE, h_lev = H_LEV, n_actions = N_ACTIONS, debug=False)
    reward += r # cumulative reward of the episode

    a_temp_enc = greedy_policy(sp_enc, q_values) # simulate the best action in the new state (before update)

    # update Q-values
    q_values = update_q_v1(s_enc, a_enc, r, sp_enc, a_temp_enc, q_values, alpha = LEARNING_RATE,
                gamma = DISCOUNT_FACTOR, map_size = MAP_SIZE, h_lev = H_LEV, n_actions = N_ACTIONS)
    
    # update states and halite
    s_enc = sp_enc
    current_halite = new_halite

    if (finish == True) or (steps >= 400):
        print("\nEnd episode.")
        break
# Out:
# Step number 1:
#
# Step number 2:
# Current halite:  4000.0
#
# Step number 3:
# Current halite:  4000.0
#
# Step number 4:
# Current halite:  4000.0
#
# Step number 5:
# Current halite:  4000.0
#
# Step number 6:
# Current halite:  4000.0
#
# Step number 7:
# Current halite:  4000.0
#
# Step number 8:
# Current halite:  4000.0
#
# Step number 9:
# Current halite:  4000.0
#
# Step number 10:
# Current halite:  4000.0
#
# Step number 11:
# Current halite:  4000.0
#
# Step number 12:
# Current halite:  4000.0
#
# Step number 13:
# Current halite:  4000.0
#
# Step number 14:
# Current halite:  4000.0
#
# Step number 15:
# Current halite:  4000.0
#
# Step number 16:
# Current halite:  4000.0
#
# Step number 17:
# Current halite:  4000.0
#
# Step number 18:
# Current halite:  4000.0
#
# Step number 19:
# Current halite:  4000.0
#
# Step number 20:
# Current halite:  4000.0
#
# Step number 21:
# Current halite:  4000.0
#
# Step number 22:
# Current halite:  4000.0
#
# Step number 23:
# Current halite:  4000.0
#
# Step number 24:
# Current halite:  4000.0
#
# Step number 25:
# Current halite:  4000.0
#
# Step number 26:
# Current halite:  4000.0
#
# Step number 27:
# Current halite:  4000.0
#
# Step number 28:
# Current halite:  4000.0
#
# Step number 29:
# Current halite:  4000.0
#
# Step number 30:
# Current halite:  4000.0
#
# Step number 31:
# Current halite:  4000.0
#
# Step number 32:
# Current halite:  4000.0
#
# Step number 33:
# Current halite:  4000.0
#
# Step number 34:
# Current halite:  4000.0
#
# Step number 35:
# Current halite:  4000.0
#
# Step number 36:
# Current halite:  4000.0
#
# Step number 37:
# Current halite:  4000.0
#
# Step number 38:
# Current halite:  4000.0
#
# Step number 39:
# Current halite:  4000.0
#
# Step number 40:
# Current halite:  4000.0
#
# Step number 41:
# Current halite:  4000.0
#
# Step number 42:
# Current halite:  4000.0
#
# Step number 43:
# Current halite:  4000.0
#
# Step number 44:
# Current halite:  4000.0
#
# Step number 45:
# Current halite:  4000.0
#
# Step number 46:
# Current halite:  4000.0
#
# Step number 47:
# Current halite:  4000.0
#
# Step number 48:
# Current halite:  4000.0
#
# Step number 49:
# Current halite:  4000.0
#
# Step number 50:
# Current halite:  4000.0
#
# Step number 51:
# Current halite:  4000.0
#
# Step number 52:
# Current halite:  4000.0
#
# Step number 53:
# Current halite:  4000.0
#
# Step number 54:
# Current halite:  4000.0
#
# Step number 55:
# Current halite:  4000.0
#
# Step number 56:
# Current halite:  4000.0
#
# Step number 57:
# Current halite:  4000.0
#
# Step number 58:
# Current halite:  4000.0
#
# Step number 59:
# Current halite:  4000.0
#
# Step number 60:
# Current halite:  4000.0
#
# Step number 61:
# Current halite:  4000.0
#
# Step number 62:
# Current halite:  4000.0
#
# Step number 63:
# Current halite:  4000.0
#
# Step number 64:
# Current halite:  4000.0
#
# Step number 65:
# Current halite:  4000.0
#
# Step number 66:
# Current halite:  4000.0
#
# Step number 67:
# Current halite:  4000.0
#
# Step number 68:
# Current halite:  4000.0
#
# Step number 69:
# Current halite:  4000.0
#
# Step number 70:
# Current halite:  4000.0
#
# Step number 71:
# Current halite:  4000.0
#
# Step number 72:
# Current halite:  4000.0
#
# Step number 73:
# Current halite:  4000.0
#
# Step number 74:
# Current halite:  4000.0
#
# Step number 75:
# Current halite:  4000.0
#
# Step number 76:
# Current halite:  4000.0
#
# Step number 77:
# Current halite:  4000.0
#
# Step number 78:
# Current halite:  4000.0
#
# Step number 79:
# Current halite:  4000.0
#
# Step number 80:
# Current halite:  4000.0
#
# Step number 81:
# Current halite:  4000.0
#
# Step number 82:
# Current halite:  4000.0
#
# Step number 83:
# Current halite:  4000.0
#
# Step number 84:
# Current halite:  4000.0
#
# Step number 85:
# Current halite:  4000.0
#
# Step number 86:
# Current halite:  4000.0
#
# Step number 87:
# Current halite:  4000.0
#
# Step number 88:
# Current halite:  4000.0
#
# Step number 89:
# Current halite:  4000.0
#
# Step number 90:
# Current halite:  4000.0
#
# Step number 91:
# Current halite:  4000.0
#
# Step number 92:
# Current halite:  4000.0
#
# Step number 93:
# Current halite:  4000.0
#
# Step number 94:
# Current halite:  4000.0
#
# Step number 95:
# Current halite:  4000.0
#
# Step number 96:
# Current halite:  4000.0
#
# Step number 97:
# Current halite:  4000.0
#
# Step number 98:
# Current halite:  4000.0
#
# Step number 99:
# Current halite:  4000.0
#
# Step number 100:
# Current halite:  4000.0
#
# Step number 101:
# Current halite:  4000.0
#
# Step number 102:
# Current halite:  4000.0
#
# Step number 103:
# Current halite:  4000.0
#
# Step number 104:
# Current halite:  4000.0
#
# Step number 105:
# Current halite:  4000.0
#
# Step number 106:
# Current halite:  4000.0
#
# Step number 107:
# Current halite:  4000.0
#
# Step number 108:
# Current halite:  5000.0
#
# Step number 109:
# Current halite:  5000.0
#
# Step number 110:
# Current halite:  5000.0
#
# Step number 111:
# Current halite:  5000.0
#
# Step number 112:
# Current halite:  5000.0
#
# Step number 113:
# Current halite:  5000.0
#
# Step number 114:
# Current halite:  5240.0
#
# Step number 115:
# Current halite:  5240.0
#
# Step number 116:
# Current halite:  5240.0
#
# Step number 117:
# Current halite:  5240.0
#
# Step number 118:
# Current halite:  5240.0
#
# Step number 119:
# Current halite:  5240.0
#
# Step number 120:
# Current halite:  5240.0
#
# Step number 121:
# Current halite:  5240.0
#
# Step number 122:
# Current halite:  5240.0
#
# Step number 123:
# Current halite:  5240.0
#
# Step number 124:
# Current halite:  5240.0
#
# Step number 125:
# Current halite:  5240.0
#
# Step number 126:
# Current halite:  5240.0
#
# Step number 127:
# Current halite:  5240.0
#
# Step number 128:
# Current halite:  5240.0
#
# Step number 129:
# Current halite:  5240.0
#
# Step number 130:
# Current halite:  5240.0
#
# Step number 131:
# Current halite:  5240.0
#
# Step number 132:
# Current halite:  5240.0
#
# Step number 133:
# Current halite:  5240.0
#
# Step number 134:
# Current halite:  5240.0
#
# Step number 135:
# Current halite:  5240.0
#
# Step number 136:
# Current halite:  5240.0
#
# Step number 137:
# Current halite:  5240.0
#
# Step number 138:
# Current halite:  5240.0
#
# Step number 139:
# Current halite:  5240.0
#
# Step number 140:
# Current halite:  5240.0
#
# Step number 141:
# Current halite:  5240.0
#
# Step number 142:
# Current halite:  5240.0
#
# Step number 143:
# Current halite:  5240.0
#
# Step number 144:
# Current halite:  5240.0
#
# Step number 145:
# Current halite:  5240.0
#
# Step number 146:
# Current halite:  5240.0
#
# Step number 147:
# Current halite:  5240.0
#
# Step number 148:
# Current halite:  5240.0
#
# Step number 149:
# Current halite:  5240.0
#
# Step number 150:
# Current halite:  5240.0
#
# Step number 151:
# Current halite:  5240.0
#
# Step number 152:
# Current halite:  5240.0
#
# Step number 153:
# Current halite:  5240.0
#
# Step number 154:
# Current halite:  5240.0
#
# Step number 155:
# Current halite:  5240.0
#
# Step number 156:
# Current halite:  5240.0
#
# Step number 157:
# Current halite:  5240.0
#
# Step number 158:
# Current halite:  5240.0
#
# Step number 159:
# Current halite:  5240.0
#
# Step number 160:
# Current halite:  5240.0
#
# Step number 161:
# Current halite:  5240.0
#
# Step number 162:
# Current halite:  5240.0
#
# Step number 163:
# Current halite:  5240.0
#
# Step number 164:
# Current halite:  5240.0
#
# Step number 165:
# Current halite:  5240.0
#
# Step number 166:
# Current halite:  5240.0
#
# Step number 167:
# Current halite:  5240.0
#
# Step number 168:
# Current halite:  5240.0
#
# Step number 169:
# Current halite:  5240.0
#
# Step number 170:
# Current halite:  5240.0
#
# Step number 171:
# Current halite:  5240.0
#
# Step number 172:
# Current halite:  5240.0
#
# Step number 173:
# Current halite:  5240.0
#
# Step number 174:
# Current halite:  5240.0
#
# Step number 175:
# Current halite:  5240.0
#
# Step number 176:
# Current halite:  5240.0
#
# Step number 177:
# Current halite:  5240.0
#
# Step number 178:
# Current halite:  5240.0
#
# Step number 179:
# Current halite:  5240.0
#
# Step number 180:
# Current halite:  5240.0
#
# Step number 181:
# Current halite:  5240.0
#
# Step number 182:
# Current halite:  5240.0
#
# Step number 183:
# Current halite:  5240.0
#
# Step number 184:
# Current halite:  5240.0
#
# Step number 185:
# Current halite:  5240.0
#
# Step number 186:
# Current halite:  5240.0
#
# Step number 187:
# Current halite:  5240.0
#
# Step number 188:
# Current halite:  5240.0
#
# Step number 189:
# Current halite:  5240.0
#
# Step number 190:
# Current halite:  5240.0
#
# Step number 191:
# Current halite:  5240.0
#
# Step number 192:
# Current halite:  5240.0
#
# Step number 193:
# Current halite:  5240.0
#
# Step number 194:
# Current halite:  5240.0
#
# Step number 195:
# Current halite:  5240.0
#
# Step number 196:
# Current halite:  5240.0
#
# Step number 197:
# Current halite:  5240.0
#
# Step number 198:
# Current halite:  5240.0
#
# Step number 199:
# Current halite:  5240.0
#
# Step number 200:
# Current halite:  5240.0
#
# Step number 201:
# Current halite:  5240.0
#
# Step number 202:
# Current halite:  5240.0
#
# Step number 203:
# Current halite:  5240.0
#
# Step number 204:
# Current halite:  5240.0
#
# Step number 205:
# Current halite:  5240.0
#
# Step number 206:
# Current halite:  5240.0
#
# Step number 207:
# Current halite:  5240.0
#
# Step number 208:
# Current halite:  5240.0
#
# Step number 209:
# Current halite:  5240.0
#
# Step number 210:
# Current halite:  5240.0
#
# Step number 211:
# Current halite:  5240.0
#
# Step number 212:
# Current halite:  5240.0
#
# Step number 213:
# Current halite:  5240.0
#
# Step number 214:
# Current halite:  5240.0
#
# Step number 215:
# Current halite:  6240.0
#
# Step number 216:
# Current halite:  6240.0
#
# Step number 217:
# Current halite:  6240.0
# Step number 218:
# Current halite:  6240.0
#
# Step number 219:
# Current halite:  6373.0
#
# Step number 220:
# Current halite:  6373.0
#
# Step number 221:
# Current halite:  6373.0
#
# Step number 222:
# Current halite:  6373.0
#
# Step number 223:
# Current halite:  6373.0
#
# Step number 224:
# Current halite:  6373.0
#
# Step number 225:
# Current halite:  6373.0
#
# Step number 226:
# Current halite:  6373.0
#
# Step number 227:
# Current halite:  6373.0
#
# Step number 228:
# Current halite:  6373.0
#
# Step number 229:
# Current halite:  6373.0
#
# Step number 230:
# Current halite:  6373.0
#
# Step number 231:
# Current halite:  6373.0
#
# Step number 232:
# Current halite:  6373.0
#
# Step number 233:
# Current halite:  6373.0
#
# Step number 234:
# Current halite:  6373.0
#
# Step number 235:
# Current halite:  6373.0
#
# Step number 236:
# Current halite:  6373.0
#
# Step number 237:
# Current halite:  6373.0
#
# Step number 238:
# Current halite:  6373.0
#
# Step number 239:
# Current halite:  6373.0
#
# Step number 240:
# Current halite:  6373.0
#
# Step number 241:
# Current halite:  6373.0
#
# Step number 242:
# Current halite:  6373.0
#
# Step number 243:
# Current halite:  6373.0
#
# Step number 244:
# Current halite:  6373.0
#
# Step number 245:
# Current halite:  6736.0
#
# Step number 246:
# Current halite:  6736.0
#
# Step number 247:
# Current halite:  6736.0
#
# Step number 248:
# Current halite:  6907.0
#
# Step number 249:
# Current halite:  6907.0
#
# Step number 250:
# Current halite:  6907.0
#
# Step number 251:
# Current halite:  6907.0
#
# Step number 252:
# Current halite:  6907.0
#
# Step number 253:
# Current halite:  6907.0
#
# Step number 254:
# Current halite:  6907.0
#
# Step number 255:
# Current halite:  6907.0
#
# Step number 256:
# Current halite:  6907.0
#
# Step number 257:
# Current halite:  6907.0
#
# Step number 258:
# Current halite:  6907.0
#
# Step number 259:
# Current halite:  7156.0
#
# Step number 260:
# Current halite:  7156.0
#
# Step number 261:
# Current halite:  7156.0
#
# Step number 262:
# Current halite:  7156.0
#
# Step number 263:
# Current halite:  7156.0
#
# Step number 264:
# Current halite:  7156.0
#
# Step number 265:
# Current halite:  7156.0
#
# Step number 266:
# Current halite:  7156.0
#
# Step number 267:
# Current halite:  7156.0
#
# Step number 268:
# Current halite:  7156.0
#
# Step number 269:
# Current halite:  7156.0
#
# Step number 270:
# Current halite:  7156.0
#
# Step number 271:
# Current halite:  7156.0
#
# Step number 272:
# Current halite:  7156.0
#
# Step number 273:
# Current halite:  7156.0
#
# Step number 274:
# Current halite:  7156.0
#
# Step number 275:
# Current halite:  7156.0
#
# Step number 276:
# Current halite:  7156.0
#
# Step number 277:
# Current halite:  7156.0
#
# Step number 278:
# Current halite:  7156.0
#
# Step number 279:
# Current halite:  7156.0
#
# Step number 280:
# Current halite:  7156.0
#
# Step number 281:
# Current halite:  7156.0
#
# Step number 282:
# Current halite:  7421.0
#
# Step number 283:
# Current halite:  7421.0
#
# Step number 284:
# Current halite:  7421.0
#
# Step number 285:
# Current halite:  7549.0
#
# Step number 286:
# Current halite:  7549.0
#
# Step number 287:
# Current halite:  7549.0
#
# Step number 288:
# Current halite:  7549.0
#
# Step number 289:
# Current halite:  7549.0
#
# Step number 290:
# Current halite:  7717.0
#
# Step number 291:
# Current halite:  7717.0
#
# Step number 292:
# Current halite:  7717.0
#
# Step number 293:
# Current halite:  7717.0
#
# Step number 294:
# Current halite:  7717.0
#
# Step number 295:
# Current halite:  7717.0
#
# Step number 296:
# Current halite:  7865.0
#
# Step number 297:
# Current halite:  7865.0
#
# Step number 298:
# Current halite:  7865.0
#
# Step number 299:
# Current halite:  7865.0
#
# Step number 300:
# Current halite:  7865.0
#
# Step number 301:
# Current halite:  7865.0
#
# Step number 302:
# Current halite:  7865.0
#
# Step number 303:
# Current halite:  7865.0
#
# Step number 304:
# Current halite:  7865.0
#
# Step number 305:
# Current halite:  7865.0
#
# Step number 306:
# Current halite:  7865.0
#
# Step number 307:
# Current halite:  7865.0
#
# Step number 308:
# Current halite:  7865.0
#
# Step number 309:
# Current halite:  7865.0
#
# Step number 310:
# Current halite:  7865.0
#
# Step number 311:
# Current halite:  7865.0
#
# Step number 312:
# Current halite:  7865.0
#
# Step number 313:
# Current halite:  7865.0
#
# Step number 314:
# Current halite:  7865.0
#
# Step number 315:
# Current halite:  7865.0
#
# Step number 316:
# Current halite:  7865.0
#
# Step number 317:
# Current halite:  7865.0
#
# Step number 318:
# Current halite:  7865.0
#
# Step number 319:
# Current halite:  7865.0
#
# Step number 320:
# Current halite:  7865.0
#
# Step number 321:
# Current halite:  7865.0
#
# Step number 322:
# Current halite:  7865.0
#
# Step number 323:
# Current halite:  7865.0
#
# Step number 324:
# Current halite:  7865.0
#
# Step number 325:
# Current halite:  7865.0
#
# Step number 326:
# Current halite:  7865.0
#
# Step number 327:
# Current halite:  7865.0
#
# Step number 328:
# Current halite:  7865.0
#
# Step number 329:
# Current halite:  7865.0
#
# Step number 330:
# Current halite:  7865.0
#
# Step number 331:
# Current halite:  7865.0
#
# Step number 332:
# Current halite:  7865.0
#
# Step number 333:
# Current halite:  7865.0
#
# Step number 334:
# Current halite:  7865.0
#
# Step number 335:
# Current halite:  7865.0
#
# Step number 336:
# Current halite:  7865.0
#
# Step number 337:
# Current halite:  7865.0
#
# Step number 338:
# Current halite:  7865.0
#
# Step number 339:
# Current halite:  7865.0
#
# Step number 340:
# Current halite:  7865.0
#
# Step number 341:
# Current halite:  7865.0
#
# Step number 342:
# Current halite:  7865.0
#
# Step number 343:
# Current halite:  7865.0
#
# Step number 344:
# Current halite:  7865.0
#
# Step number 345:
# Current halite:  7865.0
#
# Step number 346:
# Current halite:  7865.0
#
# Step number 347:
# Current halite:  7865.0
#
# Step number 348:
# Current halite:  7865.0
#
# Step number 349:
# Current halite:  7865.0
#
# Step number 350:
# Current halite:  7865.0
#
# Step number 351:
# Current halite:  7865.0
#
# Step number 352:
# Current halite:  7865.0
#
# Step number 353:
# Current halite:  7865.0
#
# Step number 354:
# Current halite:  7865.0
#
# Step number 355:
# Current halite:  7865.0
#
# Step number 356:
# Current halite:  7865.0
#
# Step number 357:
# Current halite:  7865.0
#
# Step number 358:
# Current halite:  7865.0
#
# Step number 359:
# Current halite:  7865.0
#
# Step number 360:
# Current halite:  7865.0
#
# Step number 361:
# Current halite:  7865.0
#
# Step number 362:
# Current halite:  7865.0
#
# Step number 363:
# Current halite:  7865.0
#
# Step number 364:
# Current halite:  7865.0
#
# Step number 365:
# Current halite:  7865.0
#
# Step number 366:
# Current halite:  7865.0
#
# Step number 367:
# Current halite:  7865.0
#
# Step number 368:
# Current halite:  7865.0
#
# Step number 369:
# Current halite:  7865.0
#
# Step number 370:
# Current halite:  7865.0
#
# Step number 371:
# Current halite:  7865.0
#
# Step number 372:
# Current halite:  7865.0
#
# Step number 373:
# Current halite:  7865.0
#
# Step number 374:
# Current halite:  8865.0
#
# Step number 375:
# Current halite:  8865.0
#
# Step number 376:
# Current halite:  8865.0
#
# Step number 377:
# Current halite:  8865.0
#
# Step number 378:
# Current halite:  8865.0
#
# Step number 379:
# Current halite:  8865.0
#
# Step number 380:
# Current halite:  8865.0
#
# Step number 381:
# Current halite:  8865.0
#
# Step number 382:
# Current halite:  8865.0
#
# Step number 383:
# Current halite:  8865.0
#
# Step number 384:
# Current halite:  8865.0
#
# Step number 385:
# Current halite:  8865.0
#
# Step number 386:
# Current halite:  8865.0
#
# Step number 387:
# Current halite:  8865.0
#
# Step number 388:
# Current halite:  8865.0
#
# Step number 389:
# Current halite:  8865.0
#
# Step number 390:
# Current halite:  8865.0
#
# Step number 391:
# Current halite:  8865.0
#
# Step number 392:
# Current halite:  8865.0
#
# Step number 393:
# Current halite:  8865.0
#
# Step number 394:
# Current halite:  8865.0
#
# Step number 395:
# Current halite:  8865.0
#
# Step number 396:
# Current halite:  8865.0
#
# Step number 397:
# Current halite:  8865.0
#
# Step number 398:
# Current halite:  8865.0
#
# Step number 399:
# Current halite:  8865.0
#
# Step number 400:
# Current halite:  8865.0
#
# End episode.

# %% [markdown]
# Once we have seen that this works, we would like once again to make a function out of it, so that we can use it more concisely. The only outputs that we need are the metrics of the episode and the updated Q-values. Since the inputs taken are a lot, it can be useful (it's just a matter of style) to define a dictionary with all the environment variables used and another one with the learning parameters maybe and then pass those dictionaries to our function.

# %%
env_dict = dict(NUM_PLAYERS = 1, TOT_TURNS = 400)
env_dict
# Out:
# {'NUM_PLAYERS': 1, 'TOT_TURNS': 400}

# %%
state_dict = dict(MAP_SIZE = 7,  H_LEV = 3, N_ACTIONS = 5)
state_dict
# Out:
# {'MAP_SIZE': 7, 'H_LEV': 3, 'N_ACTIONS': 5}

# %%
learning_dict = dict(LEARNING_RATE = 0.1, DISCOUNT_FACTOR = DISCOUNT_FACTOR , eps = EPS_START, STD_REWARD = STD_REWARD)
learning_dict
# Out:
# {'LEARNING_RATE': 0.1,
#  'DISCOUNT_FACTOR': 0.9975,
#  'eps': 0.5,
#  'STD_REWARD': -0.01}

# %%
def play_episode(q_values, eps, NUM_PLAYERS, MAP_SIZE, TOT_TURNS, N_ACTIONS, H_LEV,
                 STD_REWARD,LEARNING_RATE, DISCOUNT_FACTOR, verbose = False):
    
    env = Env.HaliteEnv(NUM_PLAYERS, MAP_SIZE, episode_lenght = TOT_TURNS) # init environment
    steps = 0
    reward = 0 # cumulative reward of the episode

    # first mandatory step
    steps = steps + 1
    if verbose:
        print("\nStep number %d:"%steps)
    action_matrix = np.full((MAP_SIZE,MAP_SIZE), -1) # no ship, no action
    shipyard_action = True # initially always choose to create a ship
    # returns the matricial state, the array of players halite and a flag that is true if it's the final turn
    state, players_halite, finish, _ = env.step(action_matrix, makeship = shipyard_action) 
    #print("Cargo layer: \n", state[:,:,2])
    current_halite = players_halite[0][0]
    s_enc = cod.encode_state(state, map_size = MAP_SIZE, h_lev = H_LEV, n_actions = N_ACTIONS, debug=False)

    while True:
        steps = steps + 1
        if verbose:
            print("\nStep number %d:"%steps)
            print("Current halite: ", current_halite)
        a_enc = e_greedy_policy(s_enc, q_values, eps = eps)
        a_mat = cod.scalar_to_matrix_action(a_enc, state, map_size = MAP_SIZE) #convert the action in matricial form

        # submit the action and get the new state
        state, players_halite, finish, _ = env.step(a_mat, makeship = False) 

        new_halite = players_halite[0][0]

        # compute the 1-ship reward as the halite increment of the player divided by the max halite 
        # plus a standard negative reward 
        r = (new_halite - current_halite)/1000 + STD_REWARD

        sp_enc = cod.encode_state(state, map_size = MAP_SIZE, h_lev = H_LEV, n_actions = N_ACTIONS, debug=False)
        reward += r # cumulative reward of the episode

        a_temp_enc = greedy_policy(sp_enc, q_values) # simulate the best action in the new state (before update)

        # update Q-values
        q_values = update_q_v1(s_enc, a_enc, r, sp_enc, a_temp_enc, q_values, alpha = LEARNING_RATE,
                    gamma = DISCOUNT_FACTOR, map_size = MAP_SIZE, h_lev = H_LEV, n_actions = N_ACTIONS)

        # update states and halite
        s_enc = sp_enc
        current_halite = new_halite

        if (finish == True) or (steps >= 400):
            if verbose:
                print("\nEnd episode.")
            break
    return q_values, reward

# %%
q_values, reward = play_episode(q_values, verbose = True, **env_dict, **state_dict, **learning_dict)
# Out:
# Step number 1:
#
# Step number 2:
# Current halite:  4000.0
#
# Step number 3:
# Current halite:  4000.0
#
# Step number 4:
# Current halite:  4000.0
#
# Step number 5:
# Current halite:  4000.0
#
# Step number 6:
# Current halite:  4000.0
#
# Step number 7:
# Current halite:  4000.0
#
# Step number 8:
# Current halite:  4000.0
#
# Step number 9:
# Current halite:  4000.0
#
# Step number 10:
# Current halite:  4000.0
#
# Step number 11:
# Current halite:  4000.0
#
# Step number 12:
# Current halite:  4000.0
#
# Step number 13:
# Current halite:  4000.0
#
# Step number 14:
# Current halite:  4000.0
#
# Step number 15:
# Current halite:  4143.0
#
# Step number 16:
# Current halite:  4143.0
#
# Step number 17:
# Current halite:  4143.0
#
# Step number 18:
# Current halite:  4143.0
#
# Step number 19:
# Current halite:  4143.0
#
# Step number 20:
# Current halite:  4143.0
#
# Step number 21:
# Current halite:  4143.0
#
# Step number 22:
# Current halite:  4143.0
#
# Step number 23:
# Current halite:  4143.0
#
# Step number 24:
# Current halite:  4143.0
#
# Step number 25:
# Current halite:  4143.0
#
# Step number 26:
# Current halite:  4143.0
#
# Step number 27:
# Current halite:  4143.0
#
# Step number 28:
# Current halite:  4143.0
#
# Step number 29:
# Current halite:  4143.0
#
# Step number 30:
# Current halite:  4143.0
#
# Step number 31:
# Current halite:  4143.0
#
# Step number 32:
# Current halite:  4143.0
#
# Step number 33:
# Current halite:  4143.0
#
# Step number 34:
# Current halite:  4143.0
#
# Step number 35:
# Current halite:  4143.0
#
# Step number 36:
# Current halite:  4143.0
#
# Step number 37:
# Current halite:  4143.0
#
# Step number 38:
# Current halite:  4143.0
#
# Step number 39:
# Current halite:  4143.0
#
# Step number 40:
# Current halite:  4143.0
#
# Step number 41:
# Current halite:  4143.0
#
# Step number 42:
# Current halite:  4143.0
#
# Step number 43:
# Current halite:  4143.0
#
# Step number 44:
# Current halite:  4143.0
#
# Step number 45:
# Current halite:  4143.0
#
# Step number 46:
# Current halite:  4143.0
#
# Step number 47:
# Current halite:  4143.0
#
# Step number 48:
# Current halite:  4143.0
#
# Step number 49:
# Current halite:  4143.0
#
# Step number 50:
# Current halite:  4143.0
#
# Step number 51:
# Current halite:  4143.0
#
# Step number 52:
# Current halite:  4143.0
#
# Step number 53:
# Current halite:  4143.0
#
# Step number 54:
# Current halite:  4143.0
#
# Step number 55:
# Current halite:  4143.0
#
# Step number 56:
# Current halite:  4143.0
#
# Step number 57:
# Current halite:  4143.0
#
# Step number 58:
# Current halite:  4143.0
#
# Step number 59:
# Current halite:  4143.0
#
# Step number 60:
# Current halite:  4143.0
#
# Step number 61:
# Current halite:  4143.0
#
# Step number 62:
# Current halite:  4143.0
#
# Step number 63:
# Current halite:  4143.0
#
# Step number 64:
# Current halite:  4143.0
#
# Step number 65:
# Current halite:  4143.0
#
# Step number 66:
# Current halite:  4143.0
#
# Step number 67:
# Current halite:  4143.0
#
# Step number 68:
# Current halite:  4143.0
#
# Step number 69:
# Current halite:  4143.0
#
# Step number 70:
# Current halite:  4143.0
#
# Step number 71:
# Current halite:  4143.0
#
# Step number 72:
# Current halite:  4143.0
#
# Step number 73:
# Current halite:  4143.0
#
# Step number 74:
# Current halite:  4143.0
#
# Step number 75:
# Current halite:  4143.0
#
# Step number 76:
# Current halite:  4143.0
#
# Step number 77:
# Current halite:  4143.0
#
# Step number 78:
# Current halite:  4143.0
#
# Step number 79:
# Current halite:  4143.0
#
# Step number 80:
# Current halite:  4143.0
#
# Step number 81:
# Current halite:  4143.0
#
# Step number 82:
# Current halite:  4143.0
#
# Step number 83:
# Current halite:  4143.0
#
# Step number 84:
# Current halite:  4143.0
#
# Step number 85:
# Current halite:  4143.0
#
# Step number 86:
# Current halite:  4143.0
#
# Step number 87:
# Current halite:  4143.0
#
# Step number 88:
# Current halite:  4143.0
#
# Step number 89:
# Current halite:  4143.0
#
# Step number 90:
# Current halite:  4143.0
#
# Step number 91:
# Current halite:  4143.0
#
# Step number 92:
# Current halite:  4143.0
#
# Step number 93:
# Current halite:  4143.0
#
# Step number 94:
# Current halite:  4143.0
#
# Step number 95:
# Current halite:  4143.0
#
# Step number 96:
# Current halite:  4143.0
#
# Step number 97:
# Current halite:  4143.0
#
# Step number 98:
# Current halite:  4143.0
#
# Step number 99:
# Current halite:  4143.0
#
# Step number 100:
# Current halite:  4143.0
#
# Step number 101:
# Current halite:  4143.0
#
# Step number 102:
# Current halite:  4143.0
#
# Step number 103:
# Current halite:  4143.0
#
# Step number 104:
# Current halite:  4143.0
#
# Step number 105:
# Current halite:  4143.0
#
# Step number 106:
# Current halite:  4143.0
#
# Step number 107:
# Current halite:  4143.0
#
# Step number 108:
# Current halite:  4143.0
#
# Step number 109:
# Current halite:  4143.0
#
# Step number 110:
# Current halite:  4143.0
#
# Step number 111:
# Current halite:  4143.0
#
# Step number 112:
# Current halite:  4143.0
#
# Step number 113:
# Current halite:  4143.0
#
# Step number 114:
# Current halite:  4143.0
#
# Step number 115:
# Current halite:  4143.0
#
# Step number 116:
# Current halite:  4143.0
#
# Step number 117:
# Current halite:  4143.0
#
# Step number 118:
# Current halite:  4143.0
#
# Step number 119:
# Current halite:  4143.0
#
# Step number 120:
# Current halite:  4143.0
#
# Step number 121:
# Current halite:  4143.0
#
# Step number 122:
# Current halite:  4143.0
#
# Step number 123:
# Current halite:  4143.0
#
# Step number 124:
# Current halite:  4143.0
#
# Step number 125:
# Current halite:  4143.0
#
# Step number 126:
# Current halite:  4143.0
#
# Step number 127:
# Current halite:  4143.0
#
# Step number 128:
# Current halite:  4143.0
#
# Step number 129:
# Current halite:  4143.0
#
# Step number 130:
# Current halite:  4143.0
#
# Step number 131:
# Current halite:  4143.0
#
# Step number 132:
# Current halite:  4143.0
#
# Step number 133:
# Current halite:  4143.0
#
# Step number 134:
# Current halite:  4143.0
#
# Step number 135:
# Current halite:  4143.0
#
# Step number 136:
# Current halite:  4143.0
#
# Step number 137:
# Current halite:  4143.0
#
# Step number 138:
# Current halite:  4143.0
#
# Step number 139:
# Current halite:  4143.0
#
# Step number 140:
# Current halite:  4143.0
#
# Step number 141:
# Current halite:  4143.0
#
# Step number 142:
# Current halite:  4143.0
#
# Step number 143:
# Current halite:  4143.0
#
# Step number 144:
# Current halite:  4143.0
#
# Step number 145:
# Current halite:  4143.0
#
# Step number 146:
# Current halite:  4143.0
#
# Step number 147:
# Current halite:  4143.0
#
# Step number 148:
# Current halite:  4143.0
#
# Step number 149:
# Current halite:  4143.0
#
# Step number 150:
# Current halite:  4143.0
#
# Step number 151:
# Current halite:  4143.0
#
# Step number 152:
# Current halite:  4143.0
#
# Step number 153:
# Current halite:  4143.0
#
# Step number 154:
# Current halite:  4143.0
#
# Step number 155:
# Current halite:  4143.0
#
# Step number 156:
# Current halite:  4143.0
#
# Step number 157:
# Current halite:  4143.0
#
# Step number 158:
# Current halite:  4143.0
#
# Step number 159:
# Current halite:  4143.0
#
# Step number 160:
# Current halite:  4143.0
#
# Step number 161:
# Current halite:  4143.0
#
# Step number 162:
# Current halite:  4143.0
#
# Step number 163:
# Current halite:  4143.0
#
# Step number 164:
# Current halite:  4143.0
#
# Step number 165:
# Current halite:  4143.0
#
# Step number 166:
# Current halite:  4143.0
#
# Step number 167:
# Current halite:  4143.0
#
# Step number 168:
# Current halite:  4143.0
#
# Step number 169:
# Current halite:  4143.0
#
# Step number 170:
# Current halite:  4143.0
#
# Step number 171:
# Current halite:  4143.0
#
# Step number 172:
# Current halite:  4143.0
#
# Step number 173:
# Current halite:  4143.0
#
# Step number 174:
# Current halite:  4143.0
#
# Step number 175:
# Current halite:  4143.0
#
# Step number 176:
# Current halite:  4143.0
#
# Step number 177:
# Current halite:  4143.0
#
# Step number 178:
# Current halite:  4143.0
#
# Step number 179:
# Current halite:  4143.0
#
# Step number 180:
# Current halite:  4143.0
#
# Step number 181:
# Current halite:  4143.0
#
# Step number 182:
# Current halite:  4143.0
#
# Step number 183:
# Current halite:  4143.0
#
# Step number 184:
# Current halite:  4143.0
#
# Step number 185:
# Current halite:  4143.0
#
# Step number 186:
# Current halite:  4143.0
#
# Step number 187:
# Current halite:  4143.0
#
# Step number 188:
# Current halite:  4143.0
#
# Step number 189:
# Current halite:  4143.0
#
# Step number 190:
# Current halite:  4143.0
#
# Step number 191:
# Current halite:  4143.0
#
# Step number 192:
# Current halite:  4143.0
#
# Step number 193:
# Current halite:  4143.0
#
# Step number 194:
# Current halite:  4143.0
#
# Step number 195:
# Current halite:  4143.0
#
# Step number 196:
# Current halite:  4143.0
#
# Step number 197:
# Current halite:  4143.0
#
# Step number 198:
# Current halite:  4143.0
#
# Step number 199:
# Current halite:  4143.0
# Step number 200:
# Current halite:  4143.0
#
# Step number 201:
# Current halite:  4143.0
#
# Step number 202:
# Current halite:  4143.0
#
# Step number 203:
# Current halite:  4143.0
#
# Step number 204:
# Current halite:  4143.0
#
# Step number 205:
# Current halite:  4143.0
#
# Step number 206:
# Current halite:  4143.0
#
# Step number 207:
# Current halite:  4143.0
#
# Step number 208:
# Current halite:  4143.0
#
# Step number 209:
# Current halite:  4143.0
#
# Step number 210:
# Current halite:  4143.0
#
# Step number 211:
# Current halite:  4143.0
#
# Step number 212:
# Current halite:  4143.0
#
# Step number 213:
# Current halite:  4143.0
#
# Step number 214:
# Current halite:  4143.0
#
# Step number 215:
# Current halite:  4143.0
#
# Step number 216:
# Current halite:  5143.0
#
# Step number 217:
# Current halite:  5143.0
#
# Step number 218:
# Current halite:  5143.0
#
# Step number 219:
# Current halite:  5143.0
#
# Step number 220:
# Current halite:  5143.0
#
# Step number 221:
# Current halite:  5143.0
#
# Step number 222:
# Current halite:  5143.0
#
# Step number 223:
# Current halite:  5143.0
#
# Step number 224:
# Current halite:  5143.0
#
# Step number 225:
# Current halite:  5143.0
#
# Step number 226:
# Current halite:  5973.0
#
# Step number 227:
# Current halite:  5973.0
#
# Step number 228:
# Current halite:  5973.0
#
# Step number 229:
# Current halite:  5973.0
#
# Step number 230:
# Current halite:  5973.0
#
# Step number 231:
# Current halite:  6098.0
#
# Step number 232:
# Current halite:  6098.0
#
# Step number 233:
# Current halite:  6098.0
#
# Step number 234:
# Current halite:  6098.0
#
# Step number 235:
# Current halite:  6098.0
#
# Step number 236:
# Current halite:  6098.0
#
# Step number 237:
# Current halite:  6098.0
#
# Step number 238:
# Current halite:  6098.0
#
# Step number 239:
# Current halite:  6640.0
#
# Step number 240:
# Current halite:  6640.0
#
# Step number 241:
# Current halite:  6640.0
#
# Step number 242:
# Current halite:  6739.0
#
# Step number 243:
# Current halite:  6739.0
#
# Step number 244:
# Current halite:  6739.0
#
# Step number 245:
# Current halite:  6739.0
#
# Step number 246:
# Current halite:  6739.0
#
# Step number 247:
# Current halite:  6739.0
#
# Step number 248:
# Current halite:  6917.0
#
# Step number 249:
# Current halite:  6917.0
#
# Step number 250:
# Current halite:  6917.0
#
# Step number 251:
# Current halite:  6917.0
#
# Step number 252:
# Current halite:  6917.0
#
# Step number 253:
# Current halite:  6917.0
#
# Step number 254:
# Current halite:  6917.0
#
# Step number 255:
# Current halite:  6917.0
#
# Step number 256:
# Current halite:  6917.0
#
# Step number 257:
# Current halite:  6917.0
#
# Step number 258:
# Current halite:  6917.0
#
# Step number 259:
# Current halite:  6917.0
#
# Step number 260:
# Current halite:  6917.0
#
# Step number 261:
# Current halite:  6917.0
#
# Step number 262:
# Current halite:  6917.0
#
# Step number 263:
# Current halite:  6917.0
#
# Step number 264:
# Current halite:  6917.0
#
# Step number 265:
# Current halite:  6917.0
#
# Step number 266:
# Current halite:  6917.0
#
# Step number 267:
# Current halite:  6917.0
#
# Step number 268:
# Current halite:  6917.0
#
# Step number 269:
# Current halite:  6917.0
#
# Step number 270:
# Current halite:  6917.0
#
# Step number 271:
# Current halite:  6917.0
#
# Step number 272:
# Current halite:  6917.0
#
# Step number 273:
# Current halite:  6917.0
#
# Step number 274:
# Current halite:  6917.0
#
# Step number 275:
# Current halite:  6917.0
#
# Step number 276:
# Current halite:  6917.0
#
# Step number 277:
# Current halite:  6917.0
#
# Step number 278:
# Current halite:  6917.0
#
# Step number 279:
# Current halite:  6917.0
#
# Step number 280:
# Current halite:  6917.0
#
# Step number 281:
# Current halite:  6917.0
#
# Step number 282:
# Current halite:  6917.0
#
# Step number 283:
# Current halite:  6917.0
#
# Step number 284:
# Current halite:  6917.0
#
# Step number 285:
# Current halite:  6917.0
#
# Step number 286:
# Current halite:  6917.0
#
# Step number 287:
# Current halite:  6917.0
#
# Step number 288:
# Current halite:  6917.0
#
# Step number 289:
# Current halite:  6917.0
#
# Step number 290:
# Current halite:  6917.0
#
# Step number 291:
# Current halite:  6917.0
#
# Step number 292:
# Current halite:  6917.0
#
# Step number 293:
# Current halite:  6917.0
#
# Step number 294:
# Current halite:  6917.0
#
# Step number 295:
# Current halite:  6917.0
#
# Step number 296:
# Current halite:  6917.0
#
# Step number 297:
# Current halite:  6917.0
#
# Step number 298:
# Current halite:  6917.0
#
# Step number 299:
# Current halite:  6917.0
#
# Step number 300:
# Current halite:  6917.0
#
# Step number 301:
# Current halite:  6917.0
#
# Step number 302:
# Current halite:  6917.0
#
# Step number 303:
# Current halite:  6917.0
#
# Step number 304:
# Current halite:  6917.0
#
# Step number 305:
# Current halite:  6917.0
#
# Step number 306:
# Current halite:  6917.0
#
# Step number 307:
# Current halite:  6917.0
#
# Step number 308:
# Current halite:  6917.0
#
# Step number 309:
# Current halite:  6917.0
#
# Step number 310:
# Current halite:  6917.0
#
# Step number 311:
# Current halite:  6917.0
#
# Step number 312:
# Current halite:  6917.0
#
# Step number 313:
# Current halite:  6917.0
#
# Step number 314:
# Current halite:  6917.0
#
# Step number 315:
# Current halite:  6917.0
#
# Step number 316:
# Current halite:  6917.0
#
# Step number 317:
# Current halite:  6917.0
#
# Step number 318:
# Current halite:  6917.0
#
# Step number 319:
# Current halite:  6917.0
#
# Step number 320:
# Current halite:  6917.0
#
# Step number 321:
# Current halite:  6917.0
#
# Step number 322:
# Current halite:  6917.0
#
# Step number 323:
# Current halite:  6917.0
#
# Step number 324:
# Current halite:  6917.0
#
# Step number 325:
# Current halite:  6917.0
#
# Step number 326:
# Current halite:  6917.0
#
# Step number 327:
# Current halite:  6917.0
#
# Step number 328:
# Current halite:  6917.0
#
# Step number 329:
# Current halite:  6917.0
#
# Step number 330:
# Current halite:  6917.0
#
# Step number 331:
# Current halite:  6917.0
#
# Step number 332:
# Current halite:  6917.0
#
# Step number 333:
# Current halite:  6917.0
#
# Step number 334:
# Current halite:  6917.0
#
# Step number 335:
# Current halite:  6917.0
#
# Step number 336:
# Current halite:  6917.0
#
# Step number 337:
# Current halite:  6917.0
#
# Step number 338:
# Current halite:  6917.0
#
# Step number 339:
# Current halite:  6917.0
#
# Step number 340:
# Current halite:  6917.0
#
# Step number 341:
# Current halite:  6917.0
#
# Step number 342:
# Current halite:  6917.0
#
# Step number 343:
# Current halite:  6917.0
#
# Step number 344:
# Current halite:  6917.0
#
# Step number 345:
# Current halite:  6917.0
#
# Step number 346:
# Current halite:  6917.0
#
# Step number 347:
# Current halite:  6917.0
#
# Step number 348:
# Current halite:  6917.0
#
# Step number 349:
# Current halite:  6917.0
#
# Step number 350:
# Current halite:  6917.0
#
# Step number 351:
# Current halite:  6917.0
#
# Step number 352:
# Current halite:  6917.0
#
# Step number 353:
# Current halite:  6917.0
#
# Step number 354:
# Current halite:  6917.0
#
# Step number 355:
# Current halite:  6917.0
#
# Step number 356:
# Current halite:  6917.0
#
# Step number 357:
# Current halite:  6917.0
#
# Step number 358:
# Current halite:  6917.0
#
# Step number 359:
# Current halite:  6917.0
#
# Step number 360:
# Current halite:  6917.0
#
# Step number 361:
# Current halite:  6917.0
#
# Step number 362:
# Current halite:  6917.0
#
# Step number 363:
# Current halite:  6917.0
#
# Step number 364:
# Current halite:  6917.0
#
# Step number 365:
# Current halite:  6917.0
#
# Step number 366:
# Current halite:  6917.0
#
# Step number 367:
# Current halite:  6917.0
#
# Step number 368:
# Current halite:  6917.0
#
# Step number 369:
# Current halite:  6917.0
#
# Step number 370:
# Current halite:  6917.0
#
# Step number 371:
# Current halite:  6917.0
#
# Step number 372:
# Current halite:  6917.0
#
# Step number 373:
# Current halite:  6917.0
#
# Step number 374:
# Current halite:  6917.0
#
# Step number 375:
# Current halite:  6917.0
#
# Step number 376:
# Current halite:  6917.0
#
# Step number 377:
# Current halite:  6917.0
#
# Step number 378:
# Current halite:  6917.0
#
# Step number 379:
# Current halite:  6917.0
#
# Step number 380:
# Current halite:  6917.0
#
# Step number 381:
# Current halite:  6917.0
#
# Step number 382:
# Current halite:  6917.0
#
# Step number 383:
# Current halite:  6917.0
#
# Step number 384:
# Current halite:  6917.0
#
# Step number 385:
# Current halite:  6917.0
#
# Step number 386:
# Current halite:  6917.0
#
# Step number 387:
# Current halite:  6917.0
#
# Step number 388:
# Current halite:  6917.0
#
# Step number 389:
# Current halite:  6917.0
#
# Step number 390:
# Current halite:  6917.0
#
# Step number 391:
# Current halite:  6917.0
#
# Step number 392:
# Current halite:  6917.0
#
# Step number 393:
# Current halite:  6917.0
#
# Step number 394:
# Current halite:  6917.0
#
# Step number 395:
# Current halite:  6917.0
#
# Step number 396:
# Current halite:  6917.0
#
# Step number 397:
# Current halite:  6917.0
#
# Step number 398:
# Current halite:  6917.0
#
# Step number 399:
# Current halite:  6917.0
#
# Step number 400:
# Current halite:  6917.0
#
# End episode.

# %%
halite_coll = (reward-STD_REWARD*(TOT_TURNS-1))*1000
halite_coll
# Out:
# 2916.9999999999977

# %% [markdown]
# It will be useful also to define a variable to store the main metric in learning, that is the reward

# %%
reward_score = np.zeros(MAX_EPOCHS) 
epochs = 0

# %% [markdown]
# Also we warmly suggest to use tnrange instead of range to monitor the progress of the learning cycle from the point of view of time. This is already provided if you are using our docker or if you followed the instructions to set up all the requirements in the anaconda environment.

# %%
#! pip install tqdm
from tqdm import tnrange

# %%
eps = EPS_START # starting value of epsilon
# generate an adaptive epsilon greedy algorithm, calibrated in order to have epsilon = 10^-4 at the last epoch
epsilons = np.array(list(map(lambda i : eps*np.exp(-i*2*np.log(10)/MAX_EPOCHS), np.arange(0,MAX_EPOCHS+1))))

for k in tnrange(MAX_EPOCHS):
    # here starts an epoch
    epochs = epochs + 1
    reward_progress = np.zeros(N_BATCH) # bunch of N_BATCH episodes
    eps = epsilons[epochs]
    # update the dictionary at each epoch with the new epsilon
    learning_dict = dict(LEARNING_RATE = 0.1, DISCOUNT_FACTOR = DISCOUNT_FACTOR , eps = eps, STD_REWARD = STD_REWARD)
    
    for i in range(N_BATCH):
        # here starts an episode
        q_values, reward = play_episode(q_values, **env_dict, **state_dict, **learning_dict)
        reward_progress[i] = reward
         
        #break # play just 1 episode
                
    #break # play just 1 epoch
    
    print("Average reward per episode in epoch %d: %.3f"%(epochs, reward_progress.mean()))
    reward_score[epochs-1] = reward_progress.mean()
    
    if epochs >= MAX_EPOCHS:
        print("Hey, I think you've had enough! Let's stop here.")
        break
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Average reward per episode in epoch 1: -1.641
# Average reward per episode in epoch 2: -1.599
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-1f8f2e8375ca> in <module>
#      13     for i in range(N_BATCH):
#      14         # here starts an episode
# ---> 15         q_values, reward = play_episode(q_values, **env_dict, **state_dict, **learning_dict)
#      16         reward_progress[i] = reward
#      17
#
# <ipython-input-17-c3aff5d8fd00> in play_episode(q_values, eps, NUM_PLAYERS, MAP_SIZE, TOT_TURNS, N_ACTIONS, H_LEV, STD_REWARD, LEARNING_RATE, DISCOUNT_FACTOR, verbose)
#      42         # update Q-values
#      43         q_values = update_q_v1(s_enc, a_enc, r, sp_enc, a_temp_enc, q_values, alpha = LEARNING_RATE,
# ---> 44                     gamma = DISCOUNT_FACTOR, map_size = MAP_SIZE, h_lev = H_LEV, n_actions = N_ACTIONS)
#      45
#      46         # update states and halite
#
# <ipython-input-6-aa1024752747> in update_q_v1(s, a, r, sp, ap, q_values, alpha, gamma, map_size, h_lev, n_actions)
#      23     """
#      24     n_cells = map_size**2
# ---> 25     s_dec = cod.decode3D(s_enc, L1 = n_cells, L2 = h_lev**6, L3 = n_actions-1)
#      26     sp_dec = cod.decode3D(sp_enc, L1 = n_cells, L2 = h_lev**6, L3 = n_actions-1)
#      27     shipy_pos = (n_cells-1)/2 #shipyard is at the center of the map
#
# ~/Projects/Python_projects/haliteRL/Modules/encode.py in decode3D(v_enc, L1, L2, L3)
#     301     """
#     302     V = np.arange(0,L1*L2*L3).reshape((L1,L2,L3))
# --> 303     v_dec = np.array([np.where(v_enc == V)[0][0],np.where(v_enc == V)[1][0], np.where(v_enc == V)[2][0]])
#     304     return v_dec
#     305
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# finally let's save our learned Q-values
np.save("Q_values/Q_values", q_valuesvaluesvaluesvaluesvalues)

# %% [markdown]
# *Congratulations!* You have trained your first halite agent! As you may have experienced if you have tried to train untill the end the agent, to wait an hour or more reading just numbers is excruciating. In the next tutorial we will see a couple of tricks to better visualize how the training is going. Also we will try to visualize after the training what can we infer from the Q-values.
